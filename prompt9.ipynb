# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
rng = np.random.uniform(0,1,1000)

plt.hist(rng, alpha=0.5, bins=100)
plt.xlabel('100 bins (x-axis)')
plt.ylabel('1000 random numbers (y-axis)')
plt.savefig('prompt9', bbox_inches='tight',facecolor='white')
